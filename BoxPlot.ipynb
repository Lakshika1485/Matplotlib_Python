# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = [12, 7, 3, 15, 18, 21, 22, 19, 25, 30, 40, 100]

# Create boxplot
plt.boxplot(data)

# Add title and show
plt.title("Boxplot Example")
plt.ylabel("Values")
plt.show()
